# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
import pandas as pd

df = pd.read_csv('samsung_sk_KOSPI.csv', names= ['date','SamsungOpen','SamsungHigh','SamsungLow','SamsungChange','SamsungVolume',
                                        'SkhynixOpen','SkhynixHigh','SkhynixLow','SkhynixClose','SkhynixVolume','SkhynixChange',
                                        'KOSPIOpen','KOSPIHigh','KOSPILow','KOSPIClose','KOSPIVolume','KOSPIChange','newscount','SamsungClose'])

df.head()
# Out:
#          date  SamsungOpen  SamsungHigh  ...  KOSPIChange  newscount  SamsungClose
# 0  2008-01-02        11180        11200  ...      -0.0230          0         10880
# 1  2008-01-03        10760        11060  ...      -0.0004          0         10920
# 2  2008-01-04        10920        10960  ...       0.0060          1         10780
# 3  2008-01-07        10360        10480  ...      -0.0176          0         10380
# 4  2008-01-08        10380        10480  ...      -0.0027          1         10320
#
# [5 rows x 20 columns]

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df.head()
# Out:
#         date  SamsungOpen  SamsungHigh  ...  year  month  day
# 0 2008-01-02        11180        11200  ...  2008      1    2
# 1 2008-01-03        10760        11060  ...  2008      1    3
# 2 2008-01-04        10920        10960  ...  2008      1    4
# 3 2008-01-07        10360        10480  ...  2008      1    7
# 4 2008-01-08        10380        10480  ...  2008      1    8
#
# [5 rows x 23 columns]

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(12,9))
plt.plot(df['date'],df['newscount'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scale_cols = ['SamsungOpen','SamsungHigh','SamsungLow','SamsungClose','SamsungVolume',
              'SkhynixOpen','SkhynixHigh','SkhynixLow','SkhynixClose','SkhynixVolume','SkhynixChange',
              'KOSPIOpen','KOSPIHigh','KOSPILow','KOSPIClose','KOSPIVolume','KOSPIChange','newscount','SamsungChange']
df_scaled = scaler.fit_transform(df[scale_cols])

df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

print(df_scaled)
# Out:
#       SamsungOpen  SamsungHigh  ...  newscount  SamsungChange
# 0        0.123810     0.115702  ...   0.000000       0.432625
# 1        0.119158     0.114256  ...   0.000000       0.526843
# 2        0.120930     0.113223  ...   0.033333       0.465308
# 3        0.114729     0.108264  ...   0.000000       0.374723
# 4        0.114950     0.108264  ...   0.033333       0.491568
# ...           ...          ...  ...        ...            ...
# 3264     0.916944     0.856405  ...   0.133333       0.490605
# 3265     0.916944     0.865702  ...   0.033333       0.540323
# 3266     0.909192     0.852273  ...   0.000000       0.468135
# 3267     0.908084     0.850207  ...   0.100000       0.517684
# 3268     0.914729     0.856405  ...   0.066667       0.504032
#
# [3269 rows x 19 columns]

# %%
TEST_SIZE = 200
WINDOW_SIZE = 20

train = df_scaled[:-TEST_SIZE]
test = df_scaled[-TEST_SIZE:]

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
import numpy as np

feature_cols = ['SamsungOpen','SamsungHigh','SamsungLow','SamsungChange','SamsungVolume',
              'SkhynixOpen','SkhynixHigh','SkhynixLow','SkhynixClose','SkhynixVolume','SkhynixChange',
              'KOSPIOpen','KOSPIHigh','KOSPILow','KOSPIClose','KOSPIVolume','KOSPIChange','newscount']
label_cols = ['SamsungClose']

train_feature = train[feature_cols]
train_label = train[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 20)

from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

x_train.shape, x_valid.shape
# Out:
# ((2439, 20, 18), (610, 20, 18))

# %%
test_feature = test[feature_cols]
test_label = test[label_cols]

test_feature.shape, test_label.shape
# Out:
# ((200, 18), (200, 1))

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 20)
test_feature.shape, test_label.shape
# Out:
# ((180, 20, 18), (180, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import GRU

model = Sequential()
model.add(GRU(17, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )

model.add(Dense(1))

# %%
import os

model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)

model_path = 'model'
filename = os.path.join(model_path, 'tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                                    epochs=200, 
                                    batch_size=16,
                                    validation_data=(x_valid, y_valid), 
                                    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/200
# 153/153 [==============================] - 4s 13ms/step - loss: 0.0383 - val_loss: 0.0010
#
# Epoch 00001: val_loss improved from inf to 0.00104, saving model to model/tmp_checkpoint.h5
# Epoch 2/200
# 153/153 [==============================] - 1s 9ms/step - loss: 9.3261e-04 - val_loss: 6.4421e-04
#
# Epoch 00002: val_loss improved from 0.00104 to 0.00064, saving model to model/tmp_checkpoint.h5
# Epoch 3/200
# 153/153 [==============================] - 2s 10ms/step - loss: 6.6284e-04 - val_loss: 4.1526e-04
#
# Epoch 00003: val_loss improved from 0.00064 to 0.00042, saving model to model/tmp_checkpoint.h5
# Epoch 4/200
# 153/153 [==============================] - 2s 10ms/step - loss: 3.3428e-04 - val_loss: 2.8200e-04
#
# Epoch 00004: val_loss improved from 0.00042 to 0.00028, saving model to model/tmp_checkpoint.h5
# Epoch 5/200
# 153/153 [==============================] - 1s 9ms/step - loss: 2.9991e-04 - val_loss: 2.5285e-04
#
# Epoch 00005: val_loss improved from 0.00028 to 0.00025, saving model to model/tmp_checkpoint.h5
# Epoch 6/200
# 153/153 [==============================] - 1s 9ms/step - loss: 2.1598e-04 - val_loss: 2.4349e-04
#
# Epoch 00006: val_loss improved from 0.00025 to 0.00024, saving model to model/tmp_checkpoint.h5
# Epoch 7/200
# 153/153 [==============================] - 2s 10ms/step - loss: 2.5447e-04 - val_loss: 2.0001e-04
#
# Epoch 00007: val_loss improved from 0.00024 to 0.00020, saving model to model/tmp_checkpoint.h5
# Epoch 8/200
# 153/153 [==============================] - 1s 9ms/step - loss: 2.3128e-04 - val_loss: 1.8336e-04
#
# Epoch 00008: val_loss improved from 0.00020 to 0.00018, saving model to model/tmp_checkpoint.h5
# Epoch 9/200
# 153/153 [==============================] - 1s 9ms/step - loss: 1.7890e-04 - val_loss: 2.2341e-04
#
# Epoch 00009: val_loss did not improve from 0.00018
# Epoch 10/200
# 153/153 [==============================] - 1s 10ms/step - loss: 2.2429e-04 - val_loss: 1.4525e-04
#
# Epoch 00010: val_loss improved from 0.00018 to 0.00015, saving model to model/tmp_checkpoint.h5
# Epoch 11/200
# 153/153 [==============================] - 1s 9ms/step - loss: 1.2324e-04 - val_loss: 1.7693e-04
#
# Epoch 00011: val_loss did not improve from 0.00015
# Epoch 12/200
# 153/153 [==============================] - 1s 9ms/step - loss: 1.5701e-04 - val_loss: 1.8208e-04
#
# Epoch 00012: val_loss did not improve from 0.00015
# Epoch 13/200
# 153/153 [==============================] - 1s 9ms/step - loss: 1.5816e-04 - val_loss: 1.6231e-04
#
# Epoch 00013: val_loss did not improve from 0.00015
# Epoch 14/200
# 153/153 [==============================] - 1s 10ms/step - loss: 1.2340e-04 - val_loss: 1.3991e-04
#
# Epoch 00014: val_loss improved from 0.00015 to 0.00014, saving model to model/tmp_checkpoint.h5
# Epoch 15/200
# 153/153 [==============================] - 2s 10ms/step - loss: 1.4954e-04 - val_loss: 1.2365e-04
#
# Epoch 00015: val_loss improved from 0.00014 to 0.00012, saving model to model/tmp_checkpoint.h5
# Epoch 16/200
# 153/153 [==============================] - 1s 9ms/step - loss: 1.4485e-04 - val_loss: 1.2073e-04
#
# Epoch 00016: val_loss improved from 0.00012 to 0.00012, saving model to model/tmp_checkpoint.h5
# Epoch 17/200
# 153/153 [==============================] - 1s 9ms/step - loss: 1.2106e-04 - val_loss: 1.0764e-04
#
# Epoch 00017: val_loss improved from 0.00012 to 0.00011, saving model to model/tmp_checkpoint.h5
# Epoch 18/200
# 153/153 [==============================] - 2s 10ms/step - loss: 1.1967e-04 - val_loss: 1.2950e-04
#
# Epoch 00018: val_loss did not improve from 0.00011
# Epoch 19/200
# 153/153 [==============================] - 1s 10ms/step - loss: 9.9069e-05 - val_loss: 1.0062e-04
#
# Epoch 00019: val_loss improved from 0.00011 to 0.00010, saving model to model/tmp_checkpoint.h5
# Epoch 20/200
# 153/153 [==============================] - 1s 9ms/step - loss: 1.0511e-04 - val_loss: 9.3109e-05
#
# Epoch 00020: val_loss improved from 0.00010 to 0.00009, saving model to model/tmp_checkpoint.h5
# Epoch 21/200
# 153/153 [==============================] - 2s 10ms/step - loss: 1.2441e-04 - val_loss: 8.9492e-05
#
# Epoch 00021: val_loss improved from 0.00009 to 0.00009, saving model to model/tmp_checkpoint.h5
# Epoch 22/200
# 153/153 [==============================] - 1s 10ms/step - loss: 1.3418e-04 - val_loss: 1.2790e-04
#
# Epoch 00022: val_loss did not improve from 0.00009
# Epoch 23/200
# 153/153 [==============================] - 1s 10ms/step - loss: 1.0857e-04 - val_loss: 1.0397e-04
#
# Epoch 00023: val_loss did not improve from 0.00009
# Epoch 24/200
# 153/153 [==============================] - 2s 10ms/step - loss: 8.6124e-05 - val_loss: 8.6967e-05
#
# Epoch 00024: val_loss improved from 0.00009 to 0.00009, saving model to model/tmp_checkpoint.h5
# Epoch 25/200
# 153/153 [==============================] - 2s 11ms/step - loss: 8.3671e-05 - val_loss: 8.3260e-05
#
# Epoch 00025: val_loss improved from 0.00009 to 0.00008, saving model to model/tmp_checkpoint.h5
# Epoch 26/200
# 153/153 [==============================] - 1s 10ms/step - loss: 1.0188e-04 - val_loss: 1.0379e-04
#
# Epoch 00026: val_loss did not improve from 0.00008
# Epoch 27/200
# 153/153 [==============================] - 1s 9ms/step - loss: 9.1527e-05 - val_loss: 9.1658e-05
#
# Epoch 00027: val_loss did not improve from 0.00008
# Epoch 28/200
# 153/153 [==============================] - 2s 10ms/step - loss: 9.1931e-05 - val_loss: 1.2292e-04
#
# Epoch 00028: val_loss did not improve from 0.00008
# Epoch 29/200
# 153/153 [==============================] - 2s 10ms/step - loss: 8.7844e-05 - val_loss: 1.2640e-04
#
# Epoch 00029: val_loss did not improve from 0.00008
# Epoch 30/200
# 153/153 [==============================] - 1s 10ms/step - loss: 1.0869e-04 - val_loss: 7.5173e-05
#
# Epoch 00030: val_loss improved from 0.00008 to 0.00008, saving model to model/tmp_checkpoint.h5
# Epoch 31/200
# 153/153 [==============================] - 2s 11ms/step - loss: 9.4891e-05 - val_loss: 7.3256e-05
#
# Epoch 00031: val_loss improved from 0.00008 to 0.00007, saving model to model/tmp_checkpoint.h5
# Epoch 32/200
# 153/153 [==============================] - 1s 10ms/step - loss: 9.6571e-05 - val_loss: 8.9365e-05
#
# Epoch 00032: val_loss did not improve from 0.00007
# Epoch 33/200
# 153/153 [==============================] - 2s 10ms/step - loss: 8.8936e-05 - val_loss: 1.2420e-04
#
# Epoch 00033: val_loss did not improve from 0.00007
# Epoch 34/200
# 153/153 [==============================] - 1s 10ms/step - loss: 1.0838e-04 - val_loss: 1.2232e-04
#
# Epoch 00034: val_loss did not improve from 0.00007
# Epoch 35/200
# 153/153 [==============================] - 1s 9ms/step - loss: 7.9729e-05 - val_loss: 8.7735e-05
#
# Epoch 00035: val_loss did not improve from 0.00007
# Epoch 36/200
# 153/153 [==============================] - 1s 9ms/step - loss: 7.7080e-05 - val_loss: 1.2739e-04
#
# Epoch 00036: val_loss did not improve from 0.00007

# %%
cd model/
# Out:
# /content/drive/My Drive/model

# %%
model.load_weights('tmp_checkpoint.h5')
pred = model.predict(test_feature)

pred.shape
# Out:
# (180, 1)

# %%
def reverse_min_max_scaling(org_x, x): #종가 예측값
    org_x_np = np.asarray(org_x) 
    x_np = np.asarray(x)
    return (x_np * (org_x_np.max() - org_x_np.min() + 1e-7)) + org_x_np.min()

# %%
test_predict = reverse_min_max_scaling(df['SamsungClose'],pred)
test_price = reverse_min_max_scaling(df['SamsungClose'],test_label)

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(12,9))
plt.plot(df.loc[3089:,['date']], df.loc[3089:,['SamsungClose']], label = 'acturl')
plt.plot(df.loc[3089:,['date']], test_predict, label = 'prediction')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>
